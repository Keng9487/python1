# %%
import requests

url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
else:
    print("下載失敗")
# Out:
# 下載成功

# %%
#Content of the response, in bytes
response.content
# Out:
# b'{\n "cwaopendata": {\n  "@xmlns": "urn:cwa:gov:tw:cwacommon:0.1",\n  "identifier": "109961bd-88d3-bedc-c3fd-c516f47ce0ac",\n  "sender": "weather@cwa.gov.tw",\n  "sent": "2023-11-13T17:00:02+08:00",\n  "status": "Actual",\n  "msgType": "Issue",\n  "source": "MFC",\n  "dataid": "C0032-001",\n  "scope": "Public",\n  "dataset": {\n   "datasetInfo": {\n    "datasetDescription": "\xe4\xb8\x89\xe5\x8d\x81\xe5\x85\xad\xe5\xb0\x8f\xe6\x99\x82\xe5\xa4\xa9\xe6\xb0\xa3\xe9\xa0\x90\xe5\xa0\xb1",\n    "issueTime": "2023-11-13T17:00:00+08:00",\n    "update": "2023-11-13T17:00:02+08:00"\n   },\n   "location": [\n    {\n     "locationName": "\xe8\x87\xba\xe5\x8c\x97\xe5\xb8\x82",\n     "weatherElement": [\n      {\n       "elementName": "Wx",\n       "time": [\n        {\n         "startTime": "2023-11-13T18:00:00+08:00",\n         "endTime": "2023-11-14T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe9\x99\xb0\xe6\x99\x82\xe5\xa4\x9a\xe9\x9b\xb2",\n          "parameterValue": "6"\n         }\n        },\n        {\n         "startTime": "2023-11-14T06:00:00+08:00",\n         "endTime": "2023-11-14T18:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe9\x99\xb0\xe7\x9f\xad\xe6\x9a\xab\xe9\x9b\xa8",\n          "parameterValue": "11"\n         }\n        },\n        {\n         "startTime": "2023-11-14T18:00:00+08:00",\n         "endTime": "2023-11-15T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe5\xa4\x9a\xe9\x9b\xb2\xe6\x99\x82\xe9\x99\xb0\xe7\x9f\xad\xe6\x9a\xab\xe9\x9b\xa8",\n          "parameterValue": "9"\n         }\n        }\n       ]\n      },\n      {\n       "elementName": "MaxT",\n       "time": [\n        {\n         "startTime": "2023-11-13T18:00:00+08:00",\n         "endTime": "2023-11-14T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "18",\n          "parameterUnit": "C"\n         }\n        },\n        {\n         "startTime": "2023-11-14T06:00:00+08:00",\n         "endTime": "2023-11-14T18:00:00+08:00",\n         "parameter": {\n          "parameterName": "22",\n          "parameterUnit": "C"\n         }\n        },\n        {\n         "startTime": "2023-11-14T18:00:00+08:00",\n         "endTime": "2023-11-15T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "20",\n          "parameterUnit": "C"\n         }\n        }\n       ]\n      },\n      {\n       "elementName": "MinT",\n       "time": [\n        {\n         "startTime": "2023-11-13T18:00:00+08:00",\n         "endTime": "2023-11-14T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "18",\n          "parameterUnit": "C"\n         }\n        },\n        {\n         "startTime": "2023-11-14T06:00:00+08:00",\n         "endTime": "2023-11-14T18:00:00+08:00",\n         "parameter": {\n          "parameterName": "18",\n          "parameterUnit": "C"\n         }\n        },\n        {\n         "startTime": "2023-11-14T18:00:00+08:00",\n         "endTime": "2023-11-15T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "20",\n          "parameterUnit": "C"\n         }\n        }\n       ]\n      },\n      {\n       "elementName": "CI",\n       "time": [\n        {\n         "startTime": "2023-11-13T18:00:00+08:00",\n         "endTime": "2023-11-14T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe7\xa8\x8d\xe6\x9c\x89\xe5\xaf\x92\xe6\x84\x8f"\n         }\n        },\n        {\n         "startTime": "2023-11-14T06:00:00+08:00",\n         "endTime": "2023-11-14T18:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe7\xa8\x8d\xe6\x9c\x89\xe5\xaf\x92\xe6\x84\x8f\xe8\x87\xb3\xe8\x88\x92\xe9\x81\xa9"\n         }\n        },\n        {\n         "startTime": "2023-11-14T18:00:00+08:00",\n         "endTime": "2023-11-15T06:00:00+08:00",\n         "parameter": {\n          "parameterName": "\xe7\xa8\x8d\xe6\x9c\x89\xe5\xaf\x92\xe6\x84\x8f"\n         }\n        }\n       ]\n      },\n       ...

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
with open("天氣預報.json",mode="w",encoding="utf-8") as file:
    file.write(response.text)
