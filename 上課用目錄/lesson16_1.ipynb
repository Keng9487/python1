# %%
#使用2維的list
#50個學生,每個學生的分數
import random
students = []
for j in range(50):
    scores = [] 
    for i in range(5):
        scores.append(random.randint(50,100))
    students.append(scores)

students
# Out:
# [[85, 97, 62, 59, 97],
#  [61, 77, 88, 50, 84],
#  [75, 81, 57, 87, 80],
#  [72, 80, 61, 67, 91],
#  [100, 67, 97, 82, 83],
#  [74, 92, 83, 78, 87],
#  [80, 92, 77, 75, 73],
#  [61, 60, 51, 88, 78],
#  [68, 92, 63, 96, 88],
#  [71, 57, 74, 65, 51],
#  [85, 79, 86, 63, 59],
#  [75, 89, 51, 83, 88],
#  [72, 75, 51, 54, 85],
#  [78, 68, 77, 59, 91],
#  [66, 60, 72, 58, 76],
#  [100, 81, 93, 100, 80],
#  [63, 86, 85, 99, 52],
#  [81, 90, 65, 94, 71],
#  [73, 72, 100, 53, 79],
#  [86, 74, 93, 54, 54],
#  [93, 82, 73, 56, 92],
#  [79, 91, 60, 90, 82],
#  [56, 58, 95, 72, 69],
#  [98, 54, 69, 64, 97],
#  [63, 84, 87, 50, 78],
#  [91, 65, 70, 62, 73],
#  [88, 95, 74, 74, 50],
#  [55, 67, 52, 58, 70],
#  [61, 87, 86, 76, 98],
#  [87, 84, 97, 77, 50],
#  [93, 53, 61, 87, 66],
#  [86, 50, 66, 100, 100],
#  [60, 76, 77, 60, 99],
#  [89, 63, 54, 50, 83],
#  [60, 75, 96, 86, 85],
#  [52, 54, 56, 93, 85],
#  [96, 83, 57, 90, 99],
#  [75, 55, 80, 53, 80],
#  [89, 55, 82, 86, 90],
# ...
